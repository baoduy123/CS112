# %%
a = input().strip()
b = input().strip()
c = 0
mydict = {}
for i in range(len(b)-1):
  mydict[b[i:i+2]] = 1 
mydict
for i in range(0,len(a)-1):
  if a[i:i+2] in mydict:
    c += 1 
print(c)
# Out:
# ABBACAB
# BCABB
# 4

# %%
text = "adsfdsa"
mydict = {}
for i in range(len(text)-1):
  mydict[text[i:i+2]] = 1
mydict
# Out:
# {'ad': 1, 'ds': 1, 'fd': 1, 'sa': 1, 'sf': 1}
